# %% [markdown]
# # Problem 1

# %%
# NIM/Nama : 16521124/Frendy Sanusi
# Tanggal : 1 Desember 2021
# Deskripsi : Problem 1 - Menganalisa data rumah yang disewakan di Brazil berdasarkan data PO5-02.csv

# %%
# Import library yang dibutuhkan
import pandas as pd

# %%
# Membaca data
df = pd.read_csv('P05-02.csv')
df # Menampilkan data untuk memudahkan pengerjaan
# Out:
#                 city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 0          Sao Paulo    70      2         1               1      7      acept
# 1          Sao Paulo   320      4         4               0     20      acept
# 2       Porto Alegre    80      1         1               1      6      acept
# 3       Porto Alegre    51      2         1               0      2      acept
# 4          Sao Paulo    25      1         1               0      1  not acept
# ...              ...   ...    ...       ...             ...    ...        ...
# 8226       Sao Paulo   150      3         3               2      8  not acept
# 8227    Porto Alegre    63      2         1               1      5  not acept
# 8228       Sao Paulo   285      4         4               4     17      acept
# 8229  Rio de Janeiro    70      3         3               0      8  not acept
# 8230  Rio de Janeiro   120      2         2               2      8      acept
#
# ...

# %% [markdown]
# ### 1. Banyaknya data

# %%
# 1. Menghitung banyaknya data
print('Banyaknya data adalah', len(df), 'data.')
# Out:
# Banyaknya data adalah 8231 data.

# %% [markdown]
# ### 2. Pajak bangunan per tahun terbesar

# %%
# 2. Mencari pajak bangunan per tahun terbesar
terbesar = df['property_tax'].max()

print('Pajak bangunan per tahun terbesar adalah senilai', terbesar)
df.loc[df['property_tax'] == terbesar]
# Out:
# Pajak bangunan per tahun terbesar adalah senilai 313700
#            city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 5114  Sao Paulo    42      1         2               1      6  not acept
#
#           furniture  homeowner_tax  rent_amount  property_tax  fire_insurance  \
# 5114  not furnished            690         2500        313700              32
#
#        total
# 5114  316900

# %% [markdown]
# ### 3. 5 rumah dengan harga sewa per tahun terbesar.

# %%
# 3. Mencari 5 rumah dengan harga sewa per tahun terbesar
sewa_terbesar = df.sort_values(['rent_amount'], ascending=[0])
sewa_terbesar[:5]
# Out:
#            city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 1978  Sao Paulo    80      2         1               1      1      acept
# 933   Sao Paulo   315      3         5               2     14  not acept
# 2166  Sao Paulo   285      4         5               4      6      acept
# 1302  Sao Paulo   410      4         5               5      1      acept
# 129   Sao Paulo   660      4         5               5     12      acept
#
#           furniture  homeowner_tax  rent_amount  property_tax  fire_insurance  \
# 1978  not furnished            875        24000             0             305
# 933   not furnished           4300        20000           959             254
# 2166      furnished         200000        20000          1834             254
# 1302  not furnished              0        20000             0             254
# 129       furnished           4800        20000          1750             254
#
#        total
# 1978   25180
# 933    25510
# 2166  222100
# ...

# %% [markdown]
# ### 4. Rumah yang berada di kota Rio de Janeiro

# %%
# 4. Mencari rumah yang berada di kota Rio de Janeiro
rio_de_janeiro = df.loc[df['city'] == 'Rio de Janeiro']
print('Banyak rumah yang berada di kota Rio de Janeiro adalah', len(rio_de_janeiro), 'rumah.')
rio_de_janeiro
# Out:
# Banyak rumah yang berada di kota Rio de Janeiro adalah 1394 rumah.
#                 city  area  rooms  bathroom  parking_spaces  floor     animal  \
# 5     Rio de Janeiro    72      2         1               0      7      acept
# 8     Rio de Janeiro    35      1         1               0      2      acept
# 15    Rio de Janeiro    88      2         3               1      9  not acept
# 16    Rio de Janeiro    56      2         1               0      8      acept
# 19    Rio de Janeiro    90      3         2               1      7      acept
# ...              ...   ...    ...       ...             ...    ...        ...
# 8208  Rio de Janeiro    60      2         2               0     13      acept
# 8215  Rio de Janeiro   250      3         2               1     11      acept
# 8224  Rio de Janeiro    98      2         1               0      1      acept
# 8229  Rio de Janeiro    70      3         3               0      8  not acept
# ...

# %% [markdown]
# ### 5. Nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun. Apakah berkorelasi lurus, terbalik, atau tidak berkolerasi? Jelaskan.

# %%
# 5. Menghitung nilai korelasi antara jumlah tempat parkir dengan pajak tanah per tahun
# serta menjelaskan apakah berkorelasi lurus, terbalik, atau tidak berkolerasi
print('Nilai korelasinya adalah', df['parking_spaces'].corr(df['homeowner_tax']))
# Out:
# Nilai korelasinya adalah 0.027585689636765953

# %% [markdown]
# Penjelasan:
# Berdasarkan hasil keluaran (output) dari program, kedua atribut jumlah tempat parkir dan pajak tanah per tahun korelasi bernilai positif dan mendekati angka 0. Dengan demikian, dapat disimpulkan bahwa kedua atribut ini tidak berkolerasi antara satu sama lainnya.
